# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
statlog_german_credit_data = fetch_ucirepo(id=144) 
  
# data (as pandas dataframes) 
X = statlog_german_credit_data.data.features 
y = statlog_german_credit_data.data.targets 
  
# metadata 
print(statlog_german_credit_data.metadata) 
  
# variable information 
print(statlog_german_credit_data.variables)
# Out:
# {'uci_id': 144, 'name': 'Statlog (German Credit Data)', 'repository_url': 'https://archive.ics.uci.edu/dataset/144/statlog+german+credit+data', 'data_url': 'https://archive.ics.uci.edu/static/public/144/data.csv', 'abstract': 'This dataset classifies people described by a set of attributes as good or bad credit risks. Comes in two formats (one all numeric). Also comes with a cost matrix', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1000, 'num_features': 20, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Other', 'Marital Status', 'Age', 'Occupation'], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5NC77', 'creators': ['Hans Hofmann'], 'intro_paper': None, 'additional_info': {'summary': 'Two datasets are provided.  the original dataset, in the form provided by Prof. Hofmann, contains categorical/symbolic attributes and is in the file "german.data".   \r\n \r\nFor algorithms that need numerical attributes, Strathclyde University produced the file "german.data-numeric".  This file has been edited and several indicator variables added to make it suitable for algorithms which cannot cope with categorical variables.   Several attributes that are ordered categorical (such as attribute 17) have been coded as integer.    This was the form used by StatLog.\r\n\r\nThis dataset requires use of a cost matrix (see below)\r\n\r\n ..... 1        2\r\n----------------------------\r\n  1   0        1\r\n-----------------------\r\n  2   5        0\r\n\r\n(1 = Good,  2 = Bad)\r\n\r\nThe rows represent the actual classification and the columns the predicted classification.\r\n\r\nIt is worse to class a customer as good when they are bad (5), than it is to class a customer as bad when they are good (1).\r\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Attribute 1:  (qualitative)      \r\n Status of existing checking account\r\n             A11 :      ... <    0 DM\r\n\t       A12 : 0 <= ... <  200 DM\r\n\t       A13 :      ... >= 200 DM / salary assignments for at least 1 year\r\n               A14 : no checking account\r\n\r\nAttribute 2:  (numerical)\r\n\t      Duration in month\r\n\r\nAttribute 3:  (qualitative)\r\n\t      Credit history\r\n\t      A30 : no credits taken/ all credits paid back duly\r\n              A31 : all credits at this bank paid back duly\r\n\t      A32 : existing credits paid back duly till now\r\n              A33 : delay in paying off in the past\r\n\t      A34 : critical account/  other credits existing (not at this bank)\r\n\r\nAttribute 4:  (qualitative)\r\n\t      Purpose\r\n\t      A40 : car (new)\r\n\t      A41 : car (used)\r\n\t      A42 : furniture/equipment\r\n\t      A43 : radio/television\r\n\t      A44 : domestic appliances\r\n\t      A45 : repairs\r\n\t      A46 : education\r\n\t      A47 : (vacation - does not exist?)\r\n\t      A48 : retraining\r\n\t      A49 : business\r\n\t      A410 : others\r\n\r\nAttribute 5:  (numerical)\r\n\t      Credit amount\r\n\r\nAttibute 6:  (qualitative)\r\n\t      Savings account/bonds\r\n\t      A61 :          ... <  100 DM\r\n\t      A62 :   100 <= ... <  500 DM\r\n\t      A63 :   500 <= ... < 1000 DM\r\n\t      A64 :          .. >= 1000 DM\r\n              A65 :   unknown/ no savings account\r\n\r\nAttribute 7:  (qualitative)\r\n\t      Present employment since\r\n\t      A71 : unemployed\r\n\t      A72 :       ... < 1 year\r\n\t      A73 : 1  <= ... < 4 years  \r\n\t      A74 : 4  <= ... < 7 years\r\n\t      A75 :       .. >= 7 years\r\n\r\nAttribute 8:  (numerical)\r\n\t      Installment rate in percentage of disposable income\r\n\r\nAttribute 9:  (qualitative)\r\n\t      Personal status and sex\r\n\t      A91 : m ...
#            name     role         type     demographic  \
# 0    Attribute1  Feature  Categorical             NaN
# 1    Attribute2  Feature      Integer             NaN
# 2    Attribute3  Feature  Categorical             NaN
# 3    Attribute4  Feature  Categorical             NaN
# 4    Attribute5  Feature      Integer             NaN
# 5    Attribute6  Feature  Categorical             NaN
# 6    Attribute7  Feature  Categorical           Other
# 7    Attribute8  Feature      Integer             NaN
# 8    Attribute9  Feature  Categorical  Marital Status
# 9   Attribute10  Feature  Categorical             NaN
# 10  Attribute11  Feature      Integer             NaN
# 11  Attribute12  Feature  Categorical             NaN
# 12  Attribute13  Feature      Integer             Age
# 13  Attribute14  Feature  Categorical             NaN
# 14  Attribute15  Feature  Categorical           Other
# 15  Attribute16  Feature      Integer             NaN
# 16  Attribute17  Feature  Categorical      Occupation
# 17  Attribute18  Feature      Integer             NaN
# 18  Attribute19  Feature       Binary             NaN
# 19  Attribute20  Feature       Binary           Other
# 20        class   Target       Binary             NaN
#
#                                           description   units missing_values
# 0                 Status of existing checking account     NaN             no
# 1                                            Duration  months             no
# 2                                      Credit history     NaN             no
# 3                                             Purpose     NaN             no
# 4                                       Credit amount     NaN             no
# 5                               Savings account/bonds     NaN             no
# 6                            Present employment since     NaN             no
# 7   Installment rate in percentage of disposable i...     NaN             no
# 8                             Personal status and sex     NaN             no
# 9                          Other debtors / guarantors     NaN             no
# 10                            Present residence since     NaN             no
# 11                                           Property     NaN             no
# 12                                                Age   years             no
# 13                            Other installment plans     NaN             no
# 14                                            Housing     NaN             no
# 15            Number of existing credits at this bank     NaN             no
# 16                                                Job     NaN             no
# 17  Number of people being liable to provide maint...     NaN             no
# 18                                          Telephone     NaN             no
# 19                                     foreign worker     NaN             no
# 20                                  1 = Good, 2 = Bad     NaN             no

# %%
X
# Out:
#     Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0          A11           6        A34        A43        1169        A65
# 1          A12          48        A32        A43        5951        A61
# 2          A14          12        A34        A46        2096        A61
# 3          A11          42        A32        A42        7882        A61
# 4          A11          24        A33        A40        4870        A61
# ..         ...         ...        ...        ...         ...        ...
# 995        A14          12        A32        A42        1736        A61
# 996        A11          30        A32        A41        3857        A61
# 997        A14          12        A32        A43         804        A61
# 998        A11          45        A32        A43        1845        A61
# 999        A12          45        A34        A41        4576        A62
#
#     Attribute7  Attribute8 Attribute9 Attribute10  Attribute11 Attribute12  \
# 0          A75           4        A93        A101            4        A121
# 1          A73           2        A92        A101            2        A121
# 2          A74           2        A93        A101            3        A121
# 3          A74           2        A93        A103            4        A122
# 4          A73           3        A93        A101            4        A124
# ..         ...         ...        ...         ...          ...         ...
# 995        A74           3        A92        A101            4        A121
# 996        A73           4        A91        A101            4        A122
# 997        A75           4        A93        A101            4        A123
# 998        A73           4        A93        A101            4        A124
# 999        A71           3        A93        A101            4        A123
#
#      Attribute13 Attribute14 Attribute15  Attribute16 Attribute17  \
# 0             67        A143        A152            2        A173
# 1             22        A143        A152            1        A173
# 2             49        A143        A152            1        A172
# 3             45        A143        A153            1        A173
# 4             53        A143        A153            2        A173
# ..           ...         ...         ...          ...         ...
# 995           31        A143        A152            1        A172
# 996           40        A143        A152            1        A174
# 997           38        A143        A152            1        A173
# 998           23        A143        A153            1        A173
# 999           27        A143        A152            1        A173
#
#      Attribute18 Attribute19 Attribute20
# 0              1        A192        A201
# 1              1        A191        A201
# 2              2        A191        A201
# 3              2        A191        A201
# 4              2        A191        A201
# ..           ...         ...         ...
# 995            1        A191        A201
# 996            1        A192        A201
# 997            1        A191        A201
# 998            1        A192        A201
# 999            1        A191        A201
#
# [1000 rows x 20 columns]

# %%
y
# Out:
#      class
# 0        1
# 1        2
# 2        1
# 3        1
# 4        2
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      2
# 999      1
#
# [1000 rows x 1 columns]

# %%
import pandas as pd
# Ver todas las columnas sin truncar
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
datos = pd.read_csv('../../data/lendingclub/accepted_2007_to_2018Q4.csv', index_col=0)
# Out:
# /var/folders/v6/d_4300n96432y2g47c2hlw640000gn/T/ipykernel_1914/2919972701.py:1: DtypeWarning: Columns (0: member_id, 1: purpose, 2: last_credit_pull_d, 3: acc_now_delinq, 4: sec_app_inq_last_6mths, 5: hardship_reason, 6: hardship_status, 7: deferral_term, 8: hardship_end_date, 9: payment_plan_start_date, 10: hardship_length, 11: orig_projected_additional_accrued_interest, 12: settlement_status, 13: settlement_date, 14: settlement_amount) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv('../../DataExtra/accepted_2007_to_2018Q4.csv', index_col=0)

# %%
datos
# Out:
#                                                   member_id  loan_amnt  \
# id
# 68407277                                                NaN     3600.0
# 68355089                                                NaN    24700.0
# 68341763                                                NaN    20000.0
# 66310712                                                NaN    35000.0
# 68476807                                                NaN    10400.0
# ...                                                     ...        ...
# 88985880                                                NaN    40000.0
# 88224441                                                NaN    24000.0
# 88215728                                                NaN    14000.0
# Total amount funded in policy code 1: 1465324575        NaN        NaN
# Total amount funded in policy code 2: 521953170         NaN        NaN
#
#                                                   funded_amnt  \
# id
# 68407277                                               3600.0
# 68355089                                              24700.0
# 68341763                                              20000.0
# 66310712                                              35000.0
# 68476807                                              10400.0
# ...                                                       ...
# 88985880                                              40000.0
# 88224441                                              24000.0
# 88215728                                              14000.0
# Total amount funded in policy code 1: 1465324575          NaN
# Total amount funded in policy code 2: 521953170           NaN
#
#                                                   funded_amnt_inv        term  \
# id
# 68407277                                                   3600.0   36 months
# 68355089                                                  24700.0   36 months
# 68341763                                                  20000.0   60 months
# 66310712                                                  35000.0   60 months
# 68476807                                                  10400.0   60 months
# ...                                                           ...         ...
# 88985880                                                  40000.0   60 months
# 88224441                                                  24000.0   60 months
# 88215728                                                  14000.0   60 months
# Total amount funded in policy code 1: 1465324575              NaN         NaN
# Total amount funded in policy code 2: 521953170               NaN         NaN
#
#                                                   int_rate  installment grade  \
# id
# 68407277                                             13.99       123.03     C
# 68355089                                             11.99       820.28     C
# 68341763                                             10.78       432.66     B
# 66310712                                             14.85       829.90     C
# 68476807                                             22.45       289.91     F
# ...                                                    ...          ...   ...
# 88985880                                             10.49       859.56     B
# 88224441                                             14.49       564.56     C
# 88215728                                             14.49       329.33     C
# Total amount funded in policy code 1: 1465324575       NaN          NaN   NaN
# Total amount funded in policy code 2: 521953170        NaN          NaN   NaN
#
#                                                  sub_grade  \
# id
# 68407277                                                C4
# 68355089                                                C1
# 68341763                                                B4
# 66310712                                                C5
# 68476807                                                F1
# ...                                                    ...
# 88985880                                                B3
# 88224441                                                C4
# 88215728                                                C4
# Total amount funded in policy code 1: 1465324575       NaN
# Total amount funded in policy code 2: 521953170        NaN
#
#                                                                     emp_title  \
# id
# 68407277                                                              leadman
# 68355089                                                             Engineer
# 68341763                                                         truck driver
# 66310712                                          Information Systems Officer
# 68476807                                                  Contract Specialist
# ...                                                                       ...
# 88985880                                                      Vice President
# 88224441                                                      Program Manager
# 88215728                                          Customer Service Technician
# Total amount funded in policy code 1: 1465324575                          NaN
# Total amount funded in policy code 2: 521953170                           NaN
#
#                                                  emp_length home_ownership  \
# id
# 68407277                                          10+ years       MORTGAGE
# 68355089                                          10+ years       MORTGAGE
# 68341763                                          10+ years       MORTGAGE
# 66310712                                          10+ years       MORTGAGE
# 68476807                                            3 years       MORTGAGE
# ...                                                     ...            ...
# 88985880                                            9 years       MORTGAGE
# 88224441                                            6 years           RENT
# 88215728                                          10+ years       MORTGAGE
# Total amount funded in policy code 1: 1465324575        NaN            NaN
# Total amount funded in policy code 2: 521953170         NaN            NaN
#
#                                                   annual_inc  \
# id
# 68407277                                             55000.0
# 68355089                                             65000.0
# 68341763                                             63000.0
# 66310712                                            110000.0
# 68476807                                            104433.0
# ...                                                      ...
# 88985880                                            227000.0
# 88224441                                            110000.0
# 88215728                                             95000.0
# Total amount funded in policy code 1: 1465324575         NaN
# Total amount funded in policy code 2: 521953170          NaN
#
#                                                  verification_status  \
# id
# 68407277                                                Not Verified
# 68355089                                                Not Verified
# 68341763                                                Not Verified
# 66310712                                             Source Verified
# 68476807                                             Source Verified
# ...                                                              ...
# 88985880                                                    Verified
# 88224441                                                Not Verified
# 88215728                                                    Verified
# Total amount funded in policy code 1: 1465324575                 NaN
# Total amount funded in policy code 2: 521953170                  NaN
#
#                                                    issue_d  loan_status  \
# id
# 68407277                                          Dec-2015   Fully Paid
# 68355089                                          Dec-2015   Fully Paid
# 68341763                                          Dec-2015   Fully Paid
# 66310712                                          Dec-2015      Current
# 68476807                                          Dec-2015   Fully Paid
# ...                                                    ...          ...
# 88985880                                          Oct-2016      Current
# 88224441                                          Oct-2016  Charged Off
# 88215728                                          Oct-2016      Current
# Total amount funded in policy code 1: 1465324575       NaN          NaN
# Total amount funded in policy code 2: 521953170        NaN          NaN
#
#                                                  pymnt_plan  \
# id
# 68407277                                                  n
# 68355089                                                  n
# 68341763                                                  n
# 66310712                                                  n
# 68476807                                                  n
# ...                                                     ...
# 88985880                                                  n
# 88224441                                                  n
# 88215728                                                  n
# Total amount funded in policy code 1: 1465324575        NaN
# Total amount funded in policy code 2: 521953170         NaN
#
#                                                                                                 url  \
# id
# 68407277                                          https://lendingclub.com/browse/loanDetail.acti...
# 68355089                                          https://lendingclub.com/browse/loanDetail.acti...
# 68341763                                          https://lendingclub.com/browse/loanDetail.acti...
# 66310712                                          https://lendingclub.com/browse/loanDetail.acti...
# 68476807                                          https://lendingclub.com/browse/loanDetail.acti...
# ...                                                                                             ...
# 88985880                                          https://lendingclub.com/browse/loanDetail.acti...
# 88224441                                          https://lendingclub.com/browse/loanDetail.acti...
# 88215728                                          https://lendingclub.com/browse/loanDetail.acti...
# Total amount funded in policy code 1: 1465324575                                                NaN
# Total amount funded in policy code 2: 521953170                                                 NaN
#
#                                                  desc             purpose  \
# id
# 68407277                                          NaN  debt_consolidation
# 68355089                                          NaN      small_business
# 68341763                                          NaN    home_improvement
# 66310712                                          NaN  debt_consolidation
# 68476807                                          NaN      major_purchase
# ...                                               ...                 ...
# 88985880                                          NaN  debt_consolidation
# 88224441                                          NaN  debt_consolidation
# 88215728                                          NaN  debt_consolidation
# Total amount funded in policy code 1: 1465324575  NaN                 NaN
# Total amount funded in policy code 2: 521953170   NaN                 NaN
#
#                                                                title zip_code  \
# id
# 68407277                                          Debt consolidation    190xx
# 68355089                                                    Business    577xx
# 68341763                                                         NaN    605xx
# 66310712                                          Debt consolidation    076xx
# 68476807                                              Major purchase    174xx
# ...                                                              ...      ...
# 88985880                                                         NaN    907xx
# 88224441                                          Debt consolidation    334xx
# 88215728                                                         NaN    770xx
# Total amount funded in policy code 1: 1465324575                 NaN      NaN
# Total amount funded in policy code 2: 521953170                  NaN      NaN
#
#                                                  addr_state    dti  \
# id
# 68407277                                                 PA   5.91
# 68355089                                                 SD  16.06
# 68341763                                                 IL  10.78
# 66310712                                                 NJ  17.06
# 68476807                                                 PA  25.37
# ...                                                     ...    ...
# 88985880                                                 CA  12.75
# 88224441                                                 FL  18.30
# 88215728                                                 TX  23.36
# Total amount funded in policy code 1: 1465324575        NaN    NaN
# Total amount funded in policy code 2: 521953170         NaN    NaN
#
#                                                   delinq_2yrs  \
# id
# 68407277                                                  0.0
# 68355089                                                  1.0
# 68341763                                                  0.0
# 66310712                                                  0.0
# 68476807                                                  1.0
# ...                                                       ...
# 88985880                                                  7.0
# 88224441                                                  0.0
# 88215728                                                  0.0
# Total amount funded in policy code 1: 1465324575          NaN
# Total amount funded in policy code 2: 521953170           NaN
#
#                                                  earliest_cr_line  \
# id
# 68407277                                                 Aug-2003
# 68355089                                                 Dec-1999
# 68341763                                                 Aug-2000
# 66310712                                                 Sep-2008
# 68476807                                                 Jun-1998
# ...                                                           ...
# 88985880                                                 Feb-1995
# 88224441                                                 Jul-1999
# 88215728                                                 Jun-1996
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   fico_range_low  \
# id
# 68407277                                                   675.0
# 68355089                                                   715.0
# 68341763                                                   695.0
# 66310712                                                   785.0
# 68476807                                                   695.0
# ...                                                          ...
# 88985880                                                   705.0
# 88224441                                                   660.0
# 88215728                                                   660.0
# Total amount funded in policy code 1: 1465324575             NaN
# Total amount funded in policy code 2: 521953170              NaN
#
#                                                   fico_range_high  \
# id
# 68407277                                                    679.0
# 68355089                                                    719.0
# 68341763                                                    699.0
# 66310712                                                    789.0
# 68476807                                                    699.0
# ...                                                           ...
# 88985880                                                    709.0
# 88224441                                                    664.0
# 88215728                                                    664.0
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   inq_last_6mths  \
# id
# 68407277                                                     1.0
# 68355089                                                     4.0
# 68341763                                                     0.0
# 66310712                                                     0.0
# 68476807                                                     3.0
# ...                                                          ...
# 88985880                                                     1.0
# 88224441                                                     0.0
# 88215728                                                     1.0
# Total amount funded in policy code 1: 1465324575             NaN
# Total amount funded in policy code 2: 521953170              NaN
#
#                                                   mths_since_last_delinq  \
# id
# 68407277                                                            30.0
# 68355089                                                             6.0
# 68341763                                                             NaN
# 66310712                                                             NaN
# 68476807                                                            12.0
# ...                                                                  ...
# 88985880                                                             9.0
# 88224441                                                            67.0
# 88215728                                                            37.0
# Total amount funded in policy code 1: 1465324575                     NaN
# Total amount funded in policy code 2: 521953170                      NaN
#
#                                                   mths_since_last_record  \
# id
# 68407277                                                             NaN
# 68355089                                                             NaN
# 68341763                                                             NaN
# 66310712                                                             NaN
# 68476807                                                             NaN
# ...                                                                  ...
# 88985880                                                             NaN
# 88224441                                                            72.0
# 88215728                                                             NaN
# Total amount funded in policy code 1: 1465324575                     NaN
# Total amount funded in policy code 2: 521953170                      NaN
#
#                                                   open_acc  pub_rec  \
# id
# 68407277                                               7.0      0.0
# 68355089                                              22.0      0.0
# 68341763                                               6.0      0.0
# 66310712                                              13.0      0.0
# 68476807                                              12.0      0.0
# ...                                                    ...      ...
# 88985880                                               5.0      0.0
# 88224441                                              10.0      1.0
# 88215728                                               8.0      0.0
# Total amount funded in policy code 1: 1465324575       NaN      NaN
# Total amount funded in policy code 2: 521953170        NaN      NaN
#
#                                                   revol_bal  revol_util  \
# id
# 68407277                                             2765.0        29.7
# 68355089                                            21470.0        19.2
# 68341763                                             7869.0        56.2
# 66310712                                             7802.0        11.6
# 68476807                                            21929.0        64.5
# ...                                                     ...         ...
# 88985880                                             8633.0        64.9
# 88224441                                            17641.0        68.1
# 88215728                                             7662.0        54.0
# Total amount funded in policy code 1: 1465324575        NaN         NaN
# Total amount funded in policy code 2: 521953170         NaN         NaN
#
#                                                   total_acc  \
# id
# 68407277                                               13.0
# 68355089                                               38.0
# 68341763                                               18.0
# 66310712                                               17.0
# 68476807                                               35.0
# ...                                                     ...
# 88985880                                               37.0
# 88224441                                               31.0
# 88215728                                               22.0
# Total amount funded in policy code 1: 1465324575        NaN
# Total amount funded in policy code 2: 521953170         NaN
#
#                                                  initial_list_status  \
# id
# 68407277                                                           w
# 68355089                                                           w
# 68341763                                                           w
# 66310712                                                           w
# 68476807                                                           w
# ...                                                              ...
# 88985880                                                           f
# 88224441                                                           f
# 88215728                                                           w
# Total amount funded in policy code 1: 1465324575                 NaN
# Total amount funded in policy code 2: 521953170                  NaN
#
#                                                   out_prncp  out_prncp_inv  \
# id
# 68407277                                               0.00           0.00
# 68355089                                               0.00           0.00
# 68341763                                               0.00           0.00
# 66310712                                           15897.65       15897.65
# 68476807                                               0.00           0.00
# ...                                                     ...            ...
# 88985880                                           23252.59       23252.59
# 88224441                                               0.00           0.00
# 88215728                                            8456.12        8456.12
# Total amount funded in policy code 1: 1465324575        NaN            NaN
# Total amount funded in policy code 2: 521953170         NaN            NaN
#
#                                                    total_pymnt  \
# id
# 68407277                                           4421.723917
# 68355089                                          25679.660000
# 68341763                                          22705.924294
# 66310712                                          31464.010000
# 68476807                                          11740.500000
# ...                                                        ...
# 88985880                                          24903.930000
# 88224441                                           6755.400000
# 88215728                                           9621.250000
# Total amount funded in policy code 1: 1465324575           NaN
# Total amount funded in policy code 2: 521953170            NaN
#
#                                                   total_pymnt_inv  \
# id
# 68407277                                                  4421.72
# 68355089                                                 25679.66
# 68341763                                                 22705.92
# 66310712                                                 31464.01
# 68476807                                                 11740.50
# ...                                                           ...
# 88985880                                                 24903.93
# 88224441                                                  6755.40
# 88215728                                                  9621.25
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   total_rec_prncp  \
# id
# 68407277                                                  3600.00
# 68355089                                                 24700.00
# 68341763                                                 20000.00
# 66310712                                                 19102.35
# 68476807                                                 10400.00
# ...                                                           ...
# 88985880                                                 16747.41
# 88224441                                                  3521.91
# 88215728                                                  5543.88
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   total_rec_int  \
# id
# 68407277                                                 821.72
# 68355089                                                 979.66
# 68341763                                                2705.92
# 66310712                                               12361.66
# 68476807                                                1340.50
# ...                                                         ...
# 88985880                                                8156.52
# 88224441                                                3233.49
# 88215728                                                4027.96
# Total amount funded in policy code 1: 1465324575            NaN
# Total amount funded in policy code 2: 521953170             NaN
#
#                                                   total_rec_late_fee  \
# id
# 68407277                                                        0.00
# 68355089                                                        0.00
# 68341763                                                        0.00
# 66310712                                                        0.00
# 68476807                                                        0.00
# ...                                                              ...
# 88985880                                                        0.00
# 88224441                                                        0.00
# 88215728                                                       49.41
# Total amount funded in policy code 1: 1465324575                 NaN
# Total amount funded in policy code 2: 521953170                  NaN
#
#                                                   recoveries  \
# id
# 68407277                                                 0.0
# 68355089                                                 0.0
# 68341763                                                 0.0
# 66310712                                                 0.0
# 68476807                                                 0.0
# ...                                                      ...
# 88985880                                                 0.0
# 88224441                                                 0.0
# 88215728                                                 0.0
# Total amount funded in policy code 1: 1465324575         NaN
# Total amount funded in policy code 2: 521953170          NaN
#
#                                                   collection_recovery_fee  \
# id
# 68407277                                                              0.0
# 68355089                                                              0.0
# 68341763                                                              0.0
# 66310712                                                              0.0
# 68476807                                                              0.0
# ...                                                                   ...
# 88985880                                                              0.0
# 88224441                                                              0.0
# 88215728                                                              0.0
# Total amount funded in policy code 1: 1465324575                      NaN
# Total amount funded in policy code 2: 521953170                       NaN
#
#                                                  last_pymnt_d  \
# id
# 68407277                                             Jan-2019
# 68355089                                             Jun-2016
# 68341763                                             Jun-2017
# 66310712                                             Feb-2019
# 68476807                                             Jul-2016
# ...                                                       ...
# 88985880                                             Mar-2019
# 88224441                                             Oct-2017
# 88215728                                             Mar-2019
# Total amount funded in policy code 1: 1465324575          NaN
# Total amount funded in policy code 2: 521953170           NaN
#
#                                                   last_pymnt_amnt  \
# id
# 68407277                                                   122.67
# 68355089                                                   926.35
# 68341763                                                 15813.30
# 66310712                                                   829.90
# 68476807                                                 10128.96
# ...                                                           ...
# 88985880                                                   859.56
# 88224441                                                   564.56
# 88215728                                                   329.33
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                  next_pymnt_d  \
# id
# 68407277                                                  NaN
# 68355089                                                  NaN
# 68341763                                                  NaN
# 66310712                                             Apr-2019
# 68476807                                                  NaN
# ...                                                       ...
# 88985880                                             Apr-2019
# 88224441                                                  NaN
# 88215728                                             Apr-2019
# Total amount funded in policy code 1: 1465324575          NaN
# Total amount funded in policy code 2: 521953170           NaN
#
#                                                  last_credit_pull_d  \
# id
# 68407277                                                   Mar-2019
# 68355089                                                   Mar-2019
# 68341763                                                   Mar-2019
# 66310712                                                   Mar-2019
# 68476807                                                   Mar-2018
# ...                                                             ...
# 88985880                                                   Mar-2019
# 88224441                                                   Mar-2019
# 88215728                                                   Mar-2019
# Total amount funded in policy code 1: 1465324575                NaN
# Total amount funded in policy code 2: 521953170                 NaN
#
#                                                   last_fico_range_high  \
# id
# 68407277                                                         564.0
# 68355089                                                         699.0
# 68341763                                                         704.0
# 66310712                                                         679.0
# 68476807                                                         704.0
# ...                                                                ...
# 88985880                                                         724.0
# 88224441                                                         594.0
# 88215728                                                         669.0
# Total amount funded in policy code 1: 1465324575                   NaN
# Total amount funded in policy code 2: 521953170                    NaN
#
#                                                   last_fico_range_low  \
# id
# 68407277                                                        560.0
# 68355089                                                        695.0
# 68341763                                                        700.0
# 66310712                                                        675.0
# 68476807                                                        700.0
# ...                                                               ...
# 88985880                                                        720.0
# 88224441                                                        590.0
# 88215728                                                        665.0
# Total amount funded in policy code 1: 1465324575                  NaN
# Total amount funded in policy code 2: 521953170                   NaN
#
#                                                   collections_12_mths_ex_med  \
# id
# 68407277                                                                 0.0
# 68355089                                                                 0.0
# 68341763                                                                 0.0
# 66310712                                                                 0.0
# 68476807                                                                 0.0
# ...                                                                      ...
# 88985880                                                                 0.0
# 88224441                                                                 0.0
# 88215728                                                                 0.0
# Total amount funded in policy code 1: 1465324575                         NaN
# Total amount funded in policy code 2: 521953170                          NaN
#
#                                                   mths_since_last_major_derog  \
# id
# 68407277                                                                 30.0
# 68355089                                                                  NaN
# 68341763                                                                  NaN
# 66310712                                                                  NaN
# 68476807                                                                  NaN
# ...                                                                       ...
# 88985880                                                                 10.0
# 88224441                                                                 67.0
# 88215728                                                                 37.0
# Total amount funded in policy code 1: 1465324575                          NaN
# Total amount funded in policy code 2: 521953170                           NaN
#
#                                                   policy_code  \
# id
# 68407277                                                  1.0
# 68355089                                                  1.0
# 68341763                                                  1.0
# 66310712                                                  1.0
# 68476807                                                  1.0
# ...                                                       ...
# 88985880                                                  1.0
# 88224441                                                  1.0
# 88215728                                                  1.0
# Total amount funded in policy code 1: 1465324575          NaN
# Total amount funded in policy code 2: 521953170           NaN
#
#                                                  application_type  \
# id
# 68407277                                               Individual
# 68355089                                               Individual
# 68341763                                                Joint App
# 66310712                                               Individual
# 68476807                                               Individual
# ...                                                           ...
# 88985880                                               Individual
# 88224441                                               Individual
# 88215728                                               Individual
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   annual_inc_joint  dti_joint  \
# id
# 68407277                                                       NaN        NaN
# 68355089                                                       NaN        NaN
# 68341763                                                   71000.0      13.85
# 66310712                                                       NaN        NaN
# 68476807                                                       NaN        NaN
# ...                                                            ...        ...
# 88985880                                                       NaN        NaN
# 88224441                                                       NaN        NaN
# 88215728                                                       NaN        NaN
# Total amount funded in policy code 1: 1465324575               NaN        NaN
# Total amount funded in policy code 2: 521953170                NaN        NaN
#
#                                                  verification_status_joint  \
# id
# 68407277                                                               NaN
# 68355089                                                               NaN
# 68341763                                                      Not Verified
# 66310712                                                               NaN
# 68476807                                                               NaN
# ...                                                                    ...
# 88985880                                                               NaN
# 88224441                                                               NaN
# 88215728                                                               NaN
# Total amount funded in policy code 1: 1465324575                       NaN
# Total amount funded in policy code 2: 521953170                        NaN
#
#                                                   acc_now_delinq  \
# id
# 68407277                                                     0.0
# 68355089                                                     0.0
# 68341763                                                     0.0
# 66310712                                                     0.0
# 68476807                                                     0.0
# ...                                                          ...
# 88985880                                                     0.0
# 88224441                                                     0.0
# 88215728                                                     0.0
# Total amount funded in policy code 1: 1465324575             NaN
# Total amount funded in policy code 2: 521953170              NaN
#
#                                                   tot_coll_amt  tot_cur_bal  \
# id
# 68407277                                                 722.0     144904.0
# 68355089                                                   0.0     204396.0
# 68341763                                                   0.0     189699.0
# 66310712                                                   0.0     301500.0
# 68476807                                                   0.0     331730.0
# ...                                                        ...          ...
# 88985880                                                   0.0      28398.0
# 88224441                                                   0.0      62426.0
# 88215728                                                   0.0     143066.0
# Total amount funded in policy code 1: 1465324575           NaN          NaN
# Total amount funded in policy code 2: 521953170            NaN          NaN
#
#                                                   open_acc_6m  open_act_il  \
# id
# 68407277                                                  2.0          2.0
# 68355089                                                  1.0          1.0
# 68341763                                                  0.0          1.0
# 66310712                                                  1.0          1.0
# 68476807                                                  1.0          3.0
# ...                                                       ...          ...
# 88985880                                                  0.0          2.0
# 88224441                                                  0.0          2.0
# 88215728                                                  0.0          1.0
# Total amount funded in policy code 1: 1465324575          NaN          NaN
# Total amount funded in policy code 2: 521953170           NaN          NaN
#
#                                                   open_il_12m  open_il_24m  \
# id
# 68407277                                                  0.0          1.0
# 68355089                                                  0.0          1.0
# 68341763                                                  0.0          4.0
# 66310712                                                  0.0          1.0
# 68476807                                                  0.0          3.0
# ...                                                       ...          ...
# 88985880                                                  0.0          1.0
# 88224441                                                  0.0          2.0
# 88215728                                                  1.0          2.0
# Total amount funded in policy code 1: 1465324575          NaN          NaN
# Total amount funded in policy code 2: 521953170           NaN          NaN
#
#                                                   mths_since_rcnt_il  \
# id
# 68407277                                                        21.0
# 68355089                                                        19.0
# 68341763                                                        19.0
# 66310712                                                        23.0
# 68476807                                                        14.0
# ...                                                              ...
# 88985880                                                        15.0
# ...
# ...                                                              ...
# 88985880                                                         NaN
# 88224441                                                         NaN
# 88215728                                                         NaN
# Total amount funded in policy code 1: 1465324575                 NaN
# Total amount funded in policy code 2: 521953170                  NaN
#
#                                                  hardship_end_date  \
# id
# 68407277                                                       NaN
# 68355089                                                       NaN
# 68341763                                                       NaN
# 66310712                                                       NaN
# 68476807                                                       NaN
# ...                                                            ...
# 88985880                                                       NaN
# 88224441                                                       NaN
# 88215728                                                       NaN
# Total amount funded in policy code 1: 1465324575               NaN
# Total amount funded in policy code 2: 521953170                NaN
#
#                                                  payment_plan_start_date  \
# id
# 68407277                                                             NaN
# 68355089                                                             NaN
# 68341763                                                             NaN
# 66310712                                                             NaN
# 68476807                                                             NaN
# ...                                                                  ...
# 88985880                                                             NaN
# 88224441                                                             NaN
# 88215728                                                             NaN
# Total amount funded in policy code 1: 1465324575                     NaN
# Total amount funded in policy code 2: 521953170                      NaN
#
#                                                   hardship_length  \
# id
# 68407277                                                      NaN
# 68355089                                                      NaN
# 68341763                                                      NaN
# 66310712                                                      NaN
# 68476807                                                      NaN
# ...                                                           ...
# 88985880                                                      NaN
# 88224441                                                      NaN
# 88215728                                                      NaN
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
#                                                   hardship_dpd  \
# id
# 68407277                                                   NaN
# 68355089                                                   NaN
# 68341763                                                   NaN
# 66310712                                                   NaN
# 68476807                                                   NaN
# ...                                                        ...
# 88985880                                                   NaN
# 88224441                                                   NaN
# 88215728                                                   NaN
# Total amount funded in policy code 1: 1465324575           NaN
# Total amount funded in policy code 2: 521953170            NaN
#
#                                                  hardship_loan_status  \
# id
# 68407277                                                          NaN
# 68355089                                                          NaN
# 68341763                                                          NaN
# 66310712                                                          NaN
# 68476807                                                          NaN
# ...                                                               ...
# 88985880                                                          NaN
# 88224441                                                          NaN
# 88215728                                                          NaN
# Total amount funded in policy code 1: 1465324575                  NaN
# Total amount funded in policy code 2: 521953170                   NaN
#
#                                                   orig_projected_additional_accrued_interest  \
# id
# 68407277                                                                                 NaN
# 68355089                                                                                 NaN
# 68341763                                                                                 NaN
# 66310712                                                                                 NaN
# 68476807                                                                                 NaN
# ...                                                                                      ...
# 88985880                                                                                 NaN
# 88224441                                                                                 NaN
# 88215728                                                                                 NaN
# Total amount funded in policy code 1: 1465324575                                         NaN
# Total amount funded in policy code 2: 521953170                                          NaN
#
#                                                   hardship_payoff_balance_amount  \
# id
# 68407277                                                                     NaN
# 68355089                                                                     NaN
# 68341763                                                                     NaN
# 66310712                                                                     NaN
# 68476807                                                                     NaN
# ...                                                                          ...
# 88985880                                                                     NaN
# 88224441                                                                     NaN
# 88215728                                                                     NaN
# Total amount funded in policy code 1: 1465324575                             NaN
# Total amount funded in policy code 2: 521953170                              NaN
#
#                                                   hardship_last_payment_amount  \
# id
# 68407277                                                                   NaN
# 68355089                                                                   NaN
# 68341763                                                                   NaN
# 66310712                                                                   NaN
# 68476807                                                                   NaN
# ...                                                                        ...
# 88985880                                                                   NaN
# 88224441                                                                   NaN
# 88215728                                                                   NaN
# Total amount funded in policy code 1: 1465324575                           NaN
# Total amount funded in policy code 2: 521953170                            NaN
#
#                                                  disbursement_method  \
# id
# 68407277                                                        Cash
# 68355089                                                        Cash
# 68341763                                                        Cash
# 66310712                                                        Cash
# 68476807                                                        Cash
# ...                                                              ...
# 88985880                                                        Cash
# 88224441                                                        Cash
# 88215728                                                        Cash
# Total amount funded in policy code 1: 1465324575                 NaN
# Total amount funded in policy code 2: 521953170                  NaN
#
#                                                  debt_settlement_flag  \
# id
# 68407277                                                            N
# 68355089                                                            N
# 68341763                                                            N
# 66310712                                                            N
# 68476807                                                            N
# ...                                                               ...
# 88985880                                                            N
# 88224441                                                            Y
# 88215728                                                            N
# Total amount funded in policy code 1: 1465324575                  NaN
# Total amount funded in policy code 2: 521953170                   NaN
#
#                                                  debt_settlement_flag_date  \
# id
# 68407277                                                               NaN
# 68355089                                                               NaN
# 68341763                                                               NaN
# 66310712                                                               NaN
# 68476807                                                               NaN
# ...                                                                    ...
# 88985880                                                               NaN
# 88224441                                                          Mar-2019
# 88215728                                                               NaN
# Total amount funded in policy code 1: 1465324575                       NaN
# Total amount funded in policy code 2: 521953170                        NaN
#
#                                                  settlement_status  \
# id
# 68407277                                                       NaN
# 68355089                                                       NaN
# 68341763                                                       NaN
# 66310712                                                       NaN
# 68476807                                                       NaN
# ...                                                            ...
# 88985880                                                       NaN
# 88224441                                                    ACTIVE
# 88215728                                                       NaN
# Total amount funded in policy code 1: 1465324575               NaN
# Total amount funded in policy code 2: 521953170                NaN
#
#                                                  settlement_date  \
# id
# 68407277                                                     NaN
# 68355089                                                     NaN
# 68341763                                                     NaN
# 66310712                                                     NaN
# 68476807                                                     NaN
# ...                                                          ...
# 88985880                                                     NaN
# 88224441                                                Mar-2019
# 88215728                                                     NaN
# Total amount funded in policy code 1: 1465324575             NaN
# Total amount funded in policy code 2: 521953170              NaN
#
#                                                   settlement_amount  \
# id
# 68407277                                                        NaN
# 68355089                                                        NaN
# 68341763                                                        NaN
# 66310712                                                        NaN
# 68476807                                                        NaN
# ...                                                             ...
# 88985880                                                        NaN
# 88224441                                                    10000.0
# 88215728                                                        NaN
# Total amount funded in policy code 1: 1465324575                NaN
# Total amount funded in policy code 2: 521953170                 NaN
#
#                                                   settlement_percentage  \
# id
# 68407277                                                            NaN
# 68355089                                                            NaN
# 68341763                                                            NaN
# 66310712                                                            NaN
# 68476807                                                            NaN
# ...                                                                 ...
# 88985880                                                            NaN
# 88224441                                                          44.82
# 88215728                                                            NaN
# Total amount funded in policy code 1: 1465324575                    NaN
# Total amount funded in policy code 2: 521953170                     NaN
#
#                                                   settlement_term
# id
# 68407277                                                      NaN
# 68355089                                                      NaN
# 68341763                                                      NaN
# 66310712                                                      NaN
# 68476807                                                      NaN
# ...                                                           ...
# 88985880                                                      NaN
# 88224441                                                      1.0
# 88215728                                                      NaN
# Total amount funded in policy code 1: 1465324575              NaN
# Total amount funded in policy code 2: 521953170               NaN
#
# [2260701 rows x 150 columns]
